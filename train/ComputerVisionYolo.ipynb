# %%
# %pip install ultralytics 1> /dev/null 2>&1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!yolo train model=/content/drive/MyDrive/models/best6.pt data=/content/drive/MyDrive/dataset/data.yaml epochs=20 imgsz=640 optimizer='Adam'
# !yolo train model=/content/best.pt data=/content/drive/MyDrive/dataset/data.yaml epochs=200 imgsz=640
# Out:
# WARNING  user config directory is not writeable, defaulting to '/tmp/Ultralytics'.
# New https://pypi.org/project/ultralytics/8.0.117 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.116  Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
